# %% [markdown]
# <a href="https://colab.research.google.com/github/yashsj/Application/blob/master/PythonMicroProj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check if the number is a palindrome or not
def is_palindrome(x):
    # add your code here
    if(x<0):
        return False
    org=x
    rev=0
    while(x>0):
        rev=rev*10+(x%10)
        x=x//10
    if(rev!=org):
        return False
    else: 
        return True 

#Check if one string is an anagram of the other    
def is_anagrams(s, t):
    # add your code here
    d1={}
    if len(s) != len(t):
        return False;
    
    for x in s:
        if x not in d1:
            d1[x]=1
        else:
            d1[x]=d1[x]+1
    
    for y in t:
        if y not in d1:
            return False;
        else:
            if d1[y]==0:
                return False
            d1[y]=d1[y]-1
       
    return True;

#Return the top k most frequent words
def top_k_words(s, k): 
    # add your code here
    str1="!?',;."  
    output = {}
    list=[]
    for char in str1:
        s=s.replace(char,"")

    for word in s.split():
        if word not in output.keys():
            output[word] = 1
        else:
            output[word] += 1
    sorted_dict=sorted(output, key=lambda word: (-output[word], word))

    for key in sorted_dict:
        list.append(key)
    return list[:k]
   
#Calculate the Gradient descent
def gradient_descent(x, y, m, c, epochs, L=0.001):
    # add your code here
    n=len(x)
    dm=[]
    dc=[]
    y_pred=[]
    x1=[]
    for i in range(n):
        dm.append(0.0)
        dc.append(0.0)
        y_pred.append(0.0)
        x1.append(x[i][0])

    while(epochs!=0):
        for i in range(len(x1)):
            y_pred[i]=x1[i]*m+c
            dm[i]=x1[i]*(y_pred[i]-y[i])
            dc[i]=y_pred[i]-y[i]
        DM=sum(dm)/len(dm)
        DC=sum(dc)/len(dc)
        m=m-(L*DM)
        c=c-(L*DC)
        epochs-=1
    
    return m , c
#

if __name__ == "__main__": 
    
    # Test Question 1
    
    print("\nQ1")
    q1_test1 = 121
    q1_test2 = -121
    q1_test3 = 0
    q1_answer1 = is_palindrome(q1_test1)
    q1_answer2 = is_palindrome(q1_test2)
    q1_answer3 = is_palindrome(q1_test3)
    print(q1_answer1 )
    print("right answer: True")
    print("--------------")
    print(q1_answer2)
    print("right answer: False")
    print("--------------")
    print(q1_answer3)
    print("right answer: True")

    
    print("\nQ2")
    q2_test1_s = "anagram"
    q2_test1_t = "nagaram"
    q2_answer1 =  is_anagrams(q2_test1_s, q2_test1_t)
    print(q2_answer1)
    print("right answer: True")

    print("--------------")
    q2_test2_s = "python"
    q2_test2_t = "py"
    q2_answer2 =  is_anagrams(q2_test2_s, q2_test2_t)
    print(q2_answer2)
    print("right answer: False")
    print("--------------")

    # test question 3
    print("\nQ3")
    q3_test1_s = "   i love python, he    love coding python. the course is about python. "
    q3_test1_k = 2
    q3_answer = top_k_words(q3_test1_s, q3_test1_k)
    print(q3_answer)
    print("right: answer:")
    print("['python', 'love']")

    print ("\nQ4")

    x = x = [[0.18],[1.0],[0.92],[0.07],[0.85],[0.99],[0.87]]
    y = [109.85, 155.72, 137.66, 76.17, 139.75, 162.6, 151.77]
    m = 0
    c = 0
    q4_epochs200 = 200
    q4_epochs500 = 500
    q4_epochs1000 = 1000
    q4_epochs2000 = 2000
    q4_epochs3000 = 3000
    q4_answer1 = gradient_descent(x,y,m,c,q4_epochs200)
    q4_answer2 = gradient_descent(x,y,m,c,q4_epochs500)
    q4_answer3 = gradient_descent(x,y,m,c,q4_epochs1000)
    q4_answer4 = gradient_descent(x,y,m,c,q4_epochs2000)
    q4_answer5 = gradient_descent(x,y,m,c,q4_epochs3000)
    print(q4_answer1)
    print("right answer:")
    print("17.724810647355827, 22.97599012903927")
    print("--------------")
    print(q4_answer2)
    print("right answer:")
    print("35.97890301691016, 46.54235227399102")
    print("--------------")
    print(q4_answer3)
    print("right answer:")
    print("52.816639894324545, 68.05971340716786")
    print("--------------")
    print(q4_answer4)
    print("right answer:")
    print("64.56549666509812, 82.46678636085996")
    print("--------------")
    print(q4_answer5)
    print("right answer:")
    print("67.42648874428104, 85.32444456113602")
    print("--------------")
# Out:
# Q1
# True
# right answer: True
# --------------
# False
# right answer: False
# --------------
# True
# right answer: True
#
# Q2
# True
# right answer: True
# --------------
# False
# right answer: False
# --------------
#
# Q3
# ['python', 'love']
# right: answer:
# ['python', 'love']
#
# Q4
# (17.724810647355827, 22.97599012903927)
# right answer:
# 17.724810647355827, 22.97599012903927
# --------------
# (35.97890301691016, 46.54235227399102)
# right answer:
# 35.97890301691016, 46.54235227399102
# --------------
# (52.816639894324545, 68.05971340716786)
# right answer:
# 52.816639894324545, 68.05971340716786
# --------------
# (64.56549666509812, 82.46678636085996)
# right answer:
# 64.56549666509812, 82.46678636085996
# --------------
# (67.42648874428104, 85.32444456113602)
# right answer:
# 67.42648874428104, 85.32444456113602
# --------------

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/cnn_class/lena.png
# Out:
# --2021-03-13 22:55:07--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/cnn_class/lena.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘lena.png’
#
# lena.png            100%[===================>] 462.73K  --.-KB/s    in 0.04s
#
# 2021-03-13 22:55:07 (10.4 MB/s) - ‘lena.png’ saved [473831/473831]

# %%
im=Image.open('lena.png')

# %%
type(im)
arr=np.array(im)


plt.imshow(arr)
gray=arr.mean(axis=2)

# %%
wide=2000
x= (np.random.random((wide,2))-0.5) * 2
x1f=x[:,0]
x2f=x[:,1]
y=np.zeros(wide)

for i in range(len(x1f)):
  if x1f[i]<=0 and x2f[i]<=0:
    y[i]=0
  elif x1f[i]>0 and x2f[i]>0:
    y[i]=0
  else:
    y[i]=1
plt.scatter(x1f,x2f,c=y);

# %%
import numpy as np
wide=2000
x=(np.random.random((wide,2))-0.5)*2

# %%
import matplotlib.pyplot as plt

# %%
x1=x[:,0]
x2=x[:,1]

# %%
x1
# Out:
# array([-0.72702896,  0.69727576,  0.15478752, ..., -0.88425865,
#         0.03730917, -0.80681132])

# %%
x2
# Out:
# array([ 0.94952663,  0.71463009, -0.8712586 , ...,  0.78491374,
#        -0.09127789, -0.66432226])

# %%
y=np.zeros(wide)

# %%
for i in range(wide):
  if x1[i]<=0 and x2[i]<=0:
    y[i]=0
  elif x1[i]>0 and x2[i]>0:
    y[i]=0
  else:
    y[i]=1
plt.scatter(x1,x2,c=y);
plt.xlabel('XOR')
plt.ylabel('XOR')
# Out:
# Text(0, 0.5, 'XOR')

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/sbux.csv
# Out:
# --2021-03-15 00:32:15--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/sbux.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61896 (60K) [text/plain]
# Saving to: ‘sbux.csv’
#
# sbux.csv            100%[===================>]  60.45K  --.-KB/s    in 0.01s
#
# 2021-03-15 00:32:15 (4.57 MB/s) - ‘sbux.csv’ saved [61896/61896]

# %%
df=pd.read_csv('sbux.csv')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/sbux.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# !head sbux.csv
# Out:
# date,open,high,low,close,volume,Name
# 2013-02-08,27.92,28.325,27.92,28.185,7146296,SBUX
# 2013-02-11,28.26,28.26,27.93,28.07,5457354,SBUX
# 2013-02-12,28.0,28.275,27.975,28.13,8665592,SBUX
# 2013-02-13,28.23,28.23,27.75,27.915,7022056,SBUX
# 2013-02-14,27.765,27.905,27.675,27.775,8899188,SBUX
# 2013-02-15,27.805,27.85,27.085,27.17,18195730,SBUX
# 2013-02-19,27.18,27.305,27.01,27.225,11760912,SBUX
# 2013-02-20,27.3,27.42,26.59,26.655,12472506,SBUX
# 2013-02-21,26.535,26.82,26.26,26.675,13896450,SBUX

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   object
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 69.0+ KB

# %%
df.columns = 'date', 'open', 'high', 'low', 'close', 'volume', 'name'

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'name'], dtype='object')

# %%
type(df[['open','close']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[0]
# Out:
# date      2013-02-08
# open           27.92
# high          28.325
# low            27.92
# close         28.185
# volume       7146296
# name            SBUX
# Name: 0, dtype: object

# %%
df2=pd.read_csv('sbux.csv',index_col='date')

# %%
df2
# Out:
#               open    high     low   close    volume  Name
# date
# 2013-02-08  27.920  28.325  27.920  28.185   7146296  SBUX
# 2013-02-11  28.260  28.260  27.930  28.070   5457354  SBUX
# 2013-02-12  28.000  28.275  27.975  28.130   8665592  SBUX
# 2013-02-13  28.230  28.230  27.750  27.915   7022056  SBUX
# 2013-02-14  27.765  27.905  27.675  27.775   8899188  SBUX
# ...            ...     ...     ...     ...       ...   ...
# 2018-02-01  56.280  56.420  55.890  56.000  14690146  SBUX
# 2018-02-02  55.900  56.320  55.700  55.770  15358909  SBUX
# 2018-02-05  55.530  56.260  54.570  54.690  16059955  SBUX
# 2018-02-06  53.685  56.060  53.560  55.610  17415065  SBUX
# 2018-02-07  55.080  55.430  54.440  54.460  13927022  SBUX
#
# [1259 rows x 6 columns]

# %%
df2.loc['2018-02-07']
# Out:
# open         55.08
# high         55.43
# low          54.44
# close        54.46
# volume    13927022
# Name          SBUX
# Name: 2018-02-07, dtype: object

# %%
type(df2.loc['2018-02-07'])
# Out:
# pandas.core.series.Series

# %%
df[df['open']>64]
# Out:
#             date   open    high    low  close   volume  name
# 1087  2017-06-05  64.85  64.870  64.18  64.27  6809284  SBUX
# 1088  2017-06-06  64.22  64.350  64.05  64.16  5448439  SBUX
# 1089  2017-06-07  64.13  64.295  63.34  63.50  8364994  SBUX

# %%
type(df['name']!='SBUX')
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
A=np.arange(10)

# %%
A[A%2==0]
# Out:
# array([0, 2, 4, 6, 8])

# %%
A=df[['open','close']].values

# %%
A
# Out:
# array([[27.92 , 28.185],
#        [28.26 , 28.07 ],
#        [28.   , 28.13 ],
#        ...,
#        [55.53 , 54.69 ],
#        [53.685, 55.61 ],
#        [55.08 , 54.46 ]])

# %%
|

# %%
type(A)
# Out:
# numpy.ndarray

# %%
smalldf=df[['open','close']]

# %%
smalldf.to_csv('output.csv')

# %%
# !head output.csv
# Out:
# ,open,close
# 0,27.92,28.185
# 1,28.26,28.07
# 2,28.0,28.13
# 3,28.23,27.915
# 4,27.765,27.775
# 5,27.805,27.17
# 6,27.18,27.225
# 7,27.3,26.655
# 8,26.535,26.675

# %%
smalldf.to_csv('output.csv',index=False)

# %%
# !head output.csv
# Out:
# open,close
# 27.92,28.185
# 28.26,28.07
# 28.0,28.13
# 28.23,27.915
# 27.765,27.775
# 27.805,27.17
# 27.18,27.225
# 27.3,26.655
# 26.535,26.675

# %%
def datetoyear(row):
  return int(row['date'].split('-')[0])

# %%
df.apply(datetoyear,axis=1)
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2013
# 4       2013
#         ...
# 1254    2018
# 1255    2018
# 1256    2018
# 1257    2018
# 1258    2018
# Length: 1259, dtype: int64

# %%
df['year']=df.apply(datetoyear,axis=1)

# %%
df
# Out:
#             date    open    high     low   close    volume  name  year
# 0     2013-02-08  27.920  28.325  27.920  28.185   7146296  SBUX  2013
# 1     2013-02-11  28.260  28.260  27.930  28.070   5457354  SBUX  2013
# 2     2013-02-12  28.000  28.275  27.975  28.130   8665592  SBUX  2013
# 3     2013-02-13  28.230  28.230  27.750  27.915   7022056  SBUX  2013
# 4     2013-02-14  27.765  27.905  27.675  27.775   8899188  SBUX  2013
# ...          ...     ...     ...     ...     ...       ...   ...   ...
# 1254  2018-02-01  56.280  56.420  55.890  56.000  14690146  SBUX  2018
# 1255  2018-02-02  55.900  56.320  55.700  55.770  15358909  SBUX  2018
# 1256  2018-02-05  55.530  56.260  54.570  54.690  16059955  SBUX  2018
# 1257  2018-02-06  53.685  56.060  53.560  55.610  17415065  SBUX  2018
# 1258  2018-02-07  55.080  55.430  54.440  54.460  13927022  SBUX  2018
#
# [1259 rows x 8 columns]

# %%
df[['open','high','low','close']].boxplot();

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df[['open','high','low','close']]);

# %%
scatter_matrix(df[['open','high','low','close']],alpha=0.2,figsize=(8,10));

# %%
wide=2000
x=(np.random.random((wide,2))-0.5)*2

# %%
x
# Out:
# array([[ 0.29862186, -0.68396481],
#        [-0.302982  ,  0.36248337],
#        [ 0.22542281,  0.86948757],
#        ...,
#        [-0.32769538, -0.91972178],
#        [ 0.38048841,  0.29617277],
#        [-0.87746015, -0.06130981]])

# %%
x1=x[:,0]
x2=x[:,1]

# %%
x1
# Out:
# array([ 0.29862186, -0.302982  ,  0.22542281, ..., -0.32769538,
#         0.38048841, -0.87746015])

# %%
x1=x1*x1

# %%
x2=x2*x2

# %%
y=x1*x2

# %%
sum=0

# %%
sum=x1+x2+y

# %%
sum
# Out:
# array([0.59869965, 0.23525402, 0.84524099, ..., 1.04410749, 0.24518885,
#        0.77658932])

# %%
plt.scatter(x1,x2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot


def create_donut(radius, size=1000):
    # assume that arr is in polar coordinates
    arr = np.array([np.linspace(0, 2 * np.pi, size), np.random.randn(size)]).T + radius
    cartesian_arr = np.array([arr[:, 1] * np.cos(arr[:, 0]), arr[:, 1] * np.sin(arr[:, 0])]).T
    return cartesian_arr


outerCircle = create_donut(10)
innerCircle = create_donut(5)

dfo = pd.DataFrame(outerCircle, columns=["x1", "x2"])
dfo["y"] = 1
dfi = pd.DataFrame(innerCircle, columns=["x1", "x2"])
dfi["y"] = 0

# generate DataFrame for result csv
df_result = pd.concat([dfi, dfo], ignore_index=True)

df_result["x1^2"] = df_result["x1"] ** 2
df_result["x2^2"] = df_result["x2"] ** 2
df_result["x1*x2"] = df_result["x1"] * df_result["x2"]

# rearrange columns
df_result = df_result[["x1", "x2", "x1^2", "x2^2", "x1*x2", "y"]]
# shuffle to mix up "y" values
df_result = df_result.sample(frac=1.0)

df_result.to_csv("result.csv", header=False, index=False)

# plot
ax = dfo.plot(x=0, y=1, kind="scatter", color="gold")
dfi.plot(x=0, y=1, kind="scatter", color="indigo", ax=ax, figsize=(5, 5), legend=False)

plot.show()

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
x=np.linspace(-6,6,1000)

# %%
fx=norm.pdf(x,loc=0,scale=1)

# %%
plt.plot(x,fx);

# %%
Fx=norm.cdf(x,loc=0,scale=1)

# %%
plt.plot(x,Fx);

# %%
logfx=norm.logpdf(x,loc=0,scale=1)

# %%
plt.plot(x,logfx)

# %%
from PIL import Image

# %%
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/cnn_class/lena.png
# Out:
# --2021-03-17 23:18:22--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/cnn_class/lena.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘lena.png.1’
#
# lena.png.1          100%[===================>] 462.73K  --.-KB/s    in 0.04s
#
# 2021-03-17 23:18:22 (10.8 MB/s) - ‘lena.png.1’ saved [473831/473831]

# %%
im=Image.open('lena.png.1')

# %%
gray=np.mean(im,axis=2)

# %%
x=np.linspace(-6,6,50)

# %%
fx=norm.pdf(x,loc=0,scale=1)

# %%
filt=np.outer(fx,fx)

# %%
plt.imshow(filt,cmap='gray');

# %%
plt.imshow(filt)

# %%
from scipy.signal import convolve2d

# %%
out=convolve2d(gray,filt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-50c11d4ebe4e> in <module>()
# ----> 1 out=convolve2d(gray,filt)
#
# NameError: name 'gray' is not defined

# %%
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(out,cmap='gray')

# %%
Hx=[[1,0,-1],[2,0,-2],[1,0,-1]]
Hy=[[1,2,1],[0,0,-0],[-1,-2,-1]]

# %%
gx=convolve2d(gray,Hx)
gy=convolve2d(gray,Hy)

# %%
import math
g=np.sqrt(gx**2+gy**2)

# %%
plt.imshow(g)

# %%
import numpy as np
v=[1/3,1/3,1/3]

# %%
x=0
#v1=[0.0,0.0,0]
v1=np.zeros(3)
while(x!=25):
  v1=v*A
x=x+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-4df0b269bd27> in <module>()
#       3 v1=np.zeros(3)
#       4 while(x!=25):
# ----> 5   v1=v*A
#       6 x=x+1
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
type(A)
np.ndim(A)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 1

# %%
type(v)
np.ndim(v)
# Out:
# 1

# %%
type(v1)
np.ndim(v1)
# Out:
# 1

# %%
import numpy as np

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9de9b9124846> in <module>()
# ----> 1 np.matmul(A,v)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
A=[[0.3,0.6,0.1],[0.5,0.2,0.3],[0.4,0.1,0.5]]

# %%
v=[1/3,1/3,1/3]
